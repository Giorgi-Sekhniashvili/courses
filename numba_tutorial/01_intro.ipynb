# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# C:\Users\gsekhniashvili\Anaconda3\lib\site-packages\IPython\core\magics\pylab.py:160: UserWarning: pylab import has clobbered these variables: ['vectorize', 'random']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %%
from numba import jit, vectorize
import random

# %%
def monte_carlo_pi(n_samples):
    acc = 0
    for i in range(n_samples):
        x = random.random()
        y = random.random()

        if (x**2 + y**2) < 1.0:
            acc += 1
    return 4.0 * acc / n_samples

# %%
# %time monte_carlo_pi(10_000_000)
# Out:
# Wall time: 7.56 s
# 3.1417432

# %%
# jit(nopython = True): if the types of elements are different this will give an error
monte_carlo_pi = jit()(monte_carlo_pi)

# %%
# %time monte_carlo_pi(10_000_000)
# Out:
# Wall time: 299 ms
# 3.1410224

# %% [markdown]
# ### what you should avoid!!!
# 1. don't use different type of elements in lists. __njit()__ makes shure that it won't happen
# 2. don't use lists, use np.arrays
# 3. __@vectorize__ is fast decorator too. This works on a single values as well as the lists

# %%
@vectorize
def scalar_computation(num):
    if num % 2 == 0:
        return 2
    else:
        return 1

scalar_computation(15)
# Out:
# 1

# %%
def scalar_computation_on_lists(list):
    output = []
    for item in list:
        if item % 2 == 0:
            output.append(2)
        else:
            output.append(1)
    return output

# %%
test_array = list(range(100_000))

# %%
output = %time scalar_computation_on_lists(test_array)
# Out:
# Wall time: 15.6 ms

# %%
# %time scalar_computation(test_array)
# Out:
# Wall time: 7 ms
# array([2, 1, 2, ..., 1, 2, 1], dtype=int64)
